# %%
import pandas as pd
import numpy as np
import glob
from tqdm import tqdm
from nltk import ngrams
from collections import Counter
from rapidfuzz import fuzz
import os
import fasttext
from pandarallel import pandarallel
from pymystem3 import Mystem
from string import punctuation
import nltk 
import multiprocessing
from kaznlp.morphology.analyzers import AnalyzerDD
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from fastbm25 import fastbm25
from transformers import AutoTokenizer, AutoModel
import torch
import spacy
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords

cores = int(multiprocessing.cpu_count()/2)
pandarallel.initialize(progress_bar=False, nb_workers=cores)

os.environ['TOKENIZERS_PARALLELISM']='false' #без этого возникает конфликт между bert и pandarallel

test = pd.read_csv("data/epir_test.csv")

df1 = pd.read_csv("data/epir_train/articles.csv")
df2 = pd.read_csv("data/epir_train/life_situations.csv")
df3 = pd.read_csv("data/epir_train/news.csv")
df4 = pd.read_csv("data/epir_train/services.csv")
df1_orig = df1.copy()
df2_orig = df2.copy()
df3_orig = df3.copy()
df4_orig = df4.copy()
df1['file'] = "articles"
df2['file'] = "life_situations"
df3['file'] = 'news'
df4['file'] = 'services'
### ПРЕДОБРАБОТКА
#articles
df1 = df1.rename({'content':'body'}, axis=1)
#news
df2['title'] = df2['title_main'].fillna("") + " " + df2['title_sub'].fillna("")
df2 = df2.rename({'instruction':'body', 
            'URL':'url'}, axis=1)
df2 = df2[['Unnamed: 0', 'id', 'sys_lang', 'title','body', 'url','file']]
#news
df3 = df3.drop('short_description', axis=1)
#services
df4 = df4.drop("title", axis=1)
df4 = df4.rename({'full_title':'title'}, axis=1)
df4['body'] = df4['description'].fillna("")+" "+df4['result_description'].fillna("")
df4 = df4[['Unnamed: 0', 'id', 'sys_lang', 'title','body', 'url','file']]

### Объединение
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

df['text'] = df['title'].fillna("")+ " " + df['body'].fillna("")
df['text'] = df['text'].str.strip()
df['text'] = df['text'].str.lower()
df = df[df['text']!=''].copy()
df['text'] = df['text'].str.replace('ақпарат өзектендіру сатысында.','', regex=False)
df['text'] = df['text'].str.replace('information is being updated.','', regex=False)
df['text'] = df['text'].str.replace('информация находится на стадии актуализации. ','', regex=False)
df['text'] = df['text'].str.replace("Dear citizens of the Republic of Kazakhstan! In order to prevent the spread of coronavirus infection in the Republic of Kazakhstan, the provision of services on paper media is possible through online reservations in the service centers of the population for the period of quarantine.Public services can be obtained online, as well as some services are available in the mobile app EgovMbile, Telegram-bot eGovKzBot2 .0 and social networks Facebook and VK.".lower(), '', regex=False)
df['text'] = df['text'].str.replace("Уважаемые граждане Республики Казахстан! Для предотвращения распространения коронавирусной инфекции в Республике Казахстан оказание услуг на бумажных носителях возможно через онлайн бронирование в ЦОНах на период карантина.Государственные услуги можно получить онлайн, а также некоторые услуги и сервисы доступны в мобильном приложении EgovMobile, Telegram-боте eGovKzBot2.0 и социальных сетях Facebook и VK.".lower(), '', regex=False)
df['text'] = df['text'].str.replace("Құрметті Қазақстан Республикасының азаматтары! Қазақстан Республикасында коронавирустық инфекцияның таралуын болдырмау үшін, қағаз түрінде қызмет көрсету карантин уақытында ХҚКО-на онлайн брондау арқылы көрсетілетін болады.Мемлекеттік қызметтерді онлайн алуға болады, сонымен қатар кейбір қызметтер мен сервистер ЕgovМоbile мобильді қосымшасында, eGovKzBot2.0 Telegram-ботында және Facebook пен VK әлеуметтік жүйелерінде қолжетімді.".lower(), '', regex=False)

df['text'] = df['text'].str.strip()

# #очищаем от только p#.### без текста
df = df[~df['text'].str.contains('^p[\d\.]+$',regex=True)].copy()

#убираем другие языки
df = df[df['sys_lang'].isin(['ru','kk','qq','en'])]

# %%
#определитель языка
#TODO: определить казахскую латиницу
#можно: перевести латиницу на кириллицу, и прогнать латиницу и кириллицу
#https://fasttext.cc/docs/en/language-identification.html
model = fasttext.load_model('lid.176.bin')
def detect_language(query):
    for lang, prob in zip(*model.predict(query, k=176)):
        lang = lang.split("__")[-1]
        if lang in {'ru','kk','en'}:
            return lang
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
test['language'] = test['question'].apply(lambda x: detect_language(x))
test['language'].value_counts()

# %%
###TODO: add qq kazakh обработка
df = df[df['sys_lang'] != 'qq'].copy()

# %%
###need to download spacy en
# import sys
# !{sys.executable} -m spacy download en

# %%
#english lemmatizer
en_stopwords = set(stopwords.words('english'))
nlp = spacy.load('en_core_web_sm')

#russian lemmatizer
russian_stopwords = set(stopwords.words("russian"))
ru_stem = Mystem() 
punctuation = set(punctuation)

#kaz 'lemmatizer'
analyzer = AnalyzerDD()
analyzer.load_model(os.path.join('kaznlp', 'morphology', 'mdl'))


def lemmatize_ru(sentence):
    tokens = ru_stem.lemmatize(sentence)
    tokens = [token for token in tokens if token not in russian_stopwords\
              and token != " " \
              and token.strip() not in punctuation]
    return " ".join(tokens).strip()

def lemmatize_kk(sentence):
    tokens = word_tokenize(sentence)
    return " ".join([analyzer.analyze(token)[1][0].split("_")[0] for token in tokens if token not in punctuation])

def lemmatize_en(sentence):
    doc = nlp(sentence)
    return " ".join([token.lemma_ for token in doc \
          if (token.lemma_ not in en_stopwords) and \
          (token.lemma_ not in punctuation)])
# Out:
# [nltk_data] Downloading package stopwords to /home/maxat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['text_stemmed'] = df['text'].copy()

df.loc[df['sys_lang']=='ru','text_stemmed'] = df.loc[df['sys_lang']=='ru','text_stemmed'].parallel_apply(lambda x: lemmatize_ru(x))

df.loc[df['sys_lang']=='kk','text_stemmed'] = df.loc[df['sys_lang']=='kk','text_stemmed'].parallel_apply(lambda x: lemmatize_kk(x))

df.loc[df['sys_lang']=='en','text_stemmed'] = df.loc[df['sys_lang']=='en','text_stemmed'].parallel_apply(lambda x: lemmatize_en(x))

#на всякий случай еще предобработка
df['text_stemmed'] = df['text_stemmed'].str.lower()
df['text_stemmed'] = df['text_stemmed'].str.strip()

# %%
#разделение датасета на языки
lang2df = {}
for lang, dfTemp in df.groupby("sys_lang"):
    lang2df[lang] = {}
    lang2df[lang]['df'] = dfTemp
    
for lang in tqdm(lang2df):
    df_lang = lang2df[lang]['df']
    corpus = df_lang['text_stemmed'].values.tolist()
    ids = df_lang['Unnamed: 0'].values.tolist()
    lang2df[lang]['ids'] = ids
    lang2df[lang]['vectorizer'] = TfidfVectorizer()
    lang2df[lang]['X'] = lang2df[lang]['vectorizer'].fit_transform(corpus)
    corpus = [sent.split() for sent in corpus]
    lang2df[lang]['bm25'] = fastbm25(corpus, PARAM_K1=1.5, PARAM_B = 0.75, EPSILON=0.25) #default parameters, need to play
# Out:
# 100%|██████████| 3/3 [01:34<00:00, 31.58s/it]

# %%
##Модель для русского языка
#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-10)
    return sum_embeddings / sum_mask

tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased-sentence")
ru_bert = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased-sentence")

def get_ru_embs(sentences):
    #Tokenize sentences
    encoded_input = tokenizer(sentences, padding=True, max_length=512, truncation=True, return_tensors='pt')
    #Compute token embeddings
    with torch.no_grad():
        model_output = ru_bert(**encoded_input)
    #Perform pooling. In this case, mean pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    return sentence_embeddings

# %%
#модель для англ
from sentence_transformers import SentenceTransformer, util
bert_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device='cpu')
# bert_model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased', device='cpu')

# %%
#модель для каз
#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-10)
    return sum_embeddings / sum_mask

tokenizer_kk = AutoTokenizer.from_pretrained("kz-transformers/kaz-roberta-conversational")
kk_bert = AutoModel.from_pretrained("kz-transformers/kaz-roberta-conversational")

def get_kk_embs(sentences):
    #Tokenize sentences
    encoded_input = tokenizer_kk(sentences, padding=True, truncation=True, max_length=512, return_tensors='pt')
    #Compute token embeddings
    with torch.no_grad():
        model_output = kk_bert(**encoded_input)
    #Perform pooling. In this case, mean pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    return sentence_embeddings
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at kz-transformers/kaz-roberta-conversational and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Inference

# %%
from sklearn.metrics.pairwise import linear_kernel

test = pd.read_csv("data/epir_test.csv")
test['index'] = None
K = 3
service_coef = 1.2
for row_ind in tqdm(test.index):
    row = test.loc[row_ind]
    query = row['question'].lower()
    query_orig = query
    lang = detect_language(query)
    apply_service_coef = False
    if lang=='ru':
        query = lemmatize_ru(query)
    elif lang=='en':
        query = lemmatize_en(query)
    elif lang=='kk':
        query = lemmatize_kk(query)
    query_vec = lang2df[lang]['vectorizer'].transform([query])
    scores = linear_kernel(query_vec, lang2df[lang]['X'])[0]
    
    top_k_indices = np.argpartition(scores, -K)[-K:]
    top_k_indices = top_k_indices[np.argsort(scores[top_k_indices])][::-1]
    top_k_ids = [lang2df[lang]['ids'][ind] for ind in top_k_indices]
    dfTemp = df.set_index("Unnamed: 0").loc[top_k_ids].copy()
    if lang =='en':
        query_bert_vec = bert_model.encode([query_orig])
        bert_vecs = bert_model.encode(dfTemp['text'].values.tolist())
        bert_scores = linear_kernel(query_bert_vec, bert_vecs)[0]
        dfTemp['total_score'] = bert_scores
    elif lang=='kk':
        query_bert_vec = get_kk_embs([query_orig])
        bert_vecs = get_kk_embs(dfTemp['text'].values.tolist())
        bert_vecs = bert_vecs/torch.norm(bert_vecs, dim=1).reshape(-1,1)
        query_bert_vec = query_bert_vec/torch.norm(query_bert_vec, dim=1).reshape(-1,1)
        bert_scores = linear_kernel(query_bert_vec, bert_vecs)[0]
        dfTemp['total_score'] = bert_scores
    # elif lang=='ru':
    #     query_bert_vec = get_ru_embs([query_orig])
    #     bert_vecs = get_ru_embs(dfTemp['text'].values.tolist())
    #     bert_vecs = bert_vecs/torch.norm(bert_vecs, dim=1).reshape(-1,1)
    #     query_bert_vec = query_bert_vec/torch.norm(query_bert_vec, dim=1).reshape(-1,1)
    #     bert_scores = linear_kernel(query_bert_vec, bert_vecs)[0]
    #     dfTemp['total_score'] = bert_scores
    else:
        dfTemp['tf_idfscore'] = scores[top_k_indices]

        topK_corpus = [sent.split() for sent in dfTemp['text_stemmed'].values.tolist()]
        dfTemp['bm25_score'] = [lang2df[lang]['bm25'].similarity_bm25(query.split(),sent) for sent in topK_corpus]
        

        dfTemp['WRatio'] = dfTemp['text'].apply(lambda x: fuzz.WRatio(query_orig,x))
        dfTemp['token_sort_ratio'] = dfTemp['text'].apply(lambda x: fuzz.token_sort_ratio(query_orig,x))
        dfTemp['ratio'] = dfTemp['text'].apply(lambda x: fuzz.ratio(query_orig,x))

        score_columns = ['tf_idfscore','bm25_score']
        
        #можно суммировать еще по reciprocal rank
        # for col in score_columns:
        #     dfTemp[col] = 1/(K-dfTemp[col].argsort())
        dfTemp['bm25_score'] *= 0.4
        dfTemp['total_score'] = dfTemp[score_columns].sum(axis=1)
    
    ##коррекция для services и life_situations
    dfTemp.loc[dfTemp['file'].isin(['services','life_situations']),'total_score'] = service_coef*dfTemp.loc[dfTemp['file'].isin(['services','life_situations']),'total_score']

    dfTemp = dfTemp.sort_values('total_score', ascending=False)
    results = dfTemp.index.tolist()
    test.loc[row_ind, 'index'] = ",".join(map(str, results))
# Out:
# 100%|██████████| 124/124 [00:20<00:00,  6.15it/s]

# %%
test['index'] = test['index'].apply(lambda x: list(map(int, x.split(','))) )

# %%
pd.set_option("display.max_rows", 125)

# %%
test_vars = test.set_index('id')['index'].explode().reset_index()
test_vars = test_vars.rename({'level_0':'id'}, axis=1)
test_vars = test_vars.merge(test[['id','question']],
                how='left', on='id')
test_vars = test_vars.merge(df[['Unnamed: 0','text','file']].rename({'Unnamed: 0':'index'}, axis=1),
                       how='left', on='index')
test_vars['rank'] = test_vars.groupby('id').cumcount()+1
test_vars
# Out:
#       id   index                                           question  \
# 0      1    2049  Алғашқы медициналық-санитариялық көмек көрсете...
# 1      1  179493  Алғашқы медициналық-санитариялық көмек көрсете...
# 2      1  139729  Алғашқы медициналық-санитариялық көмек көрсете...
# 3      2     647  How can I make an online reservation for servi...
# 4      2     392  How can I make an online reservation for servi...
# ..   ...     ...                                                ...
# 367  123  204849         Can I change my name online in Kazakhstan?
# 368  123  158059         Can I change my name online in Kazakhstan?
# 369  124  128617  Documents needed for a name change in Kazakhstan.
# 370  124  204850  Documents needed for a name change in Kazakhstan.
# 371  124  203226  Documents needed for a name change in Kazakhstan.
#
#                                                   text             file  rank
# 0    алғашқы медициналық-санитариялық көмек көрсете...         services     1
# 1                   сабақ 1. алғашқы медициналық көмек             news     2
# 2    денсаулық сақтау министрлігінің басшысы қостан...             news     3
# 3    issuance of id cards to stateless persons and ...         services     1
# 4    obtaining a quarantine certificate for movemen...         services     2
# ..                                                 ...              ...   ...
# 367  how to change surname, name or patronymic chan...  life_situations     2
# 368                             changes in legislation             news     3
# 369  about changing the name, patronymic, surname t...             news     1
# 370  how to change surname, name or patronymic what...  life_situations     2
# 371  how to apostilize (legalize) documents how to ...  life_situations     3
#
# [372 rows x 6 columns]

# %%
test_vars[test_vars['rank'] ==1]
# Out:
#       id   index                                           question  \
# 0      1    2049  Алғашқы медициналық-санитариялық көмек көрсете...
# 3      2     647  How can I make an online reservation for servi...
# 6      3  155669                               Online services Egov
# 9      4  156093                          Telegram bot Egov servces
# 12     5  179713  Where can I find the latest updates and inform...
# 15     6     116  How can I obtain a certificate from an antitub...
# 18     7     116  Process for obtaining an abstract from an anti...
# 21     8     116  Are there specific eligibility criteria or req...
# 24     9    1562  Разрешение на экспорт или импорт определенных ...
# 27    10    1562  Процесс получения разрешения на экспорт и/или ...
# 30    11    1263  Сборы при подаче заявки на разрешение на экспо...
# 33    12     836  What are the specific areas eligible for recei...
# 36    13     836   Scholarships in innovative technologies relat...
# 39    14     836  How to apply for innovative scholarships in th...
# 42    15     129  Requirements for scholarships for the agroindu...
# 45    16  205625  Права и обязанности, усыновивших ребенка на ос...
# 48    17    1832  Как мне зарегистрировать усыновление и внести ...
# 51    18    1832    Свидетельство об усыновлении и рождении ребенка
# 54    19    1444                         Эмиссия в окружающую среду
# 57    20    1444  Разрешение на эмиссии в окружающую среду для о...
# 60    21    1444  Какие организации или объекты подпадают под ка...
# 63    22    1331  Что означает процедура аккредитации спортивной...
# 66    23    1331  Как можно подать заявку на аккредитацию местно...
# 69    24    1331  Документы и условия для получения свидетельств...
# 72    25   90244                   Университетке құжаттарды тапсыру
# 75    26  152099             Карантин кезінде оқу мекемелеріне түсу
# 78    27   60233  Оформить услугу на бумажных носителях через он...
# 81    28   31237  Услуги и сервисы доступны в мобильном приложен...
# 84    29    1322  Отличия между апостилированием и консульской л...
# 87    30    1571  Какие коллекторские агентства попадают в реест...
# 90    31    1571       Процесс регистрации коллекторского агентства
# 93    32    1571  В каких случаях может быть отказано в учетной ...
# 96    33    1859  Виды деятельности связаны с разработкой, произ...
# 99    34    1859  Какие условия и требования сопутствуют выдаче ...
# 102   35    1859  Что делать, если мне отказали в выдаче лицензи...
# 105   36  141793  How can I check the status of my recent funds ...
# 108   37     565  What is the process for rectifying a mistaken ...
# 267   90  206920                                    Итті серуендету
# 270   91   28739                       Үй жануарларын далаға шығару
# 273   92   65893                               Болашақ бағдарламасы
# 276   93   60244                                 Шетелге оқуға түсу
# 279   94  203594                               Әскери билет ақпарат
# 282   95  167456                            Мектепке керек құжаттар
# 285   96   51862                         Баланы 1 сынгыпқа дайындау
# 288   97   51559                        Көлік жүргізуге керек құжат
# 291   98  205765             Әлеуметтік көмекті қалай алуға болады?
# 294   99   68078                            Әлеуметтік көмек сомасы
# 297  100   71882                                   Шағын бизнес ашу
# 300  101  177611            Жеке кәсіпкер болу үшін не істеу керек?
# 303  102    2518                     Қазақстандағы тұрғын үй көмегі
# 306  103  188924            Қазақстан азаматтығын қалай ала аламын?
# 309  104  177611           Жолда көлікпен соғылсам, не істеу керек?
# 312  105  187519                     Дәрігерге қалай жазыла аламын?
# 315  106  206038                          Steps to buy an apartment
# 318  107  206037                                  Mortgage programs
# 321  108  203678           What is an IRP card for disabled people?
# 324  109  203678  Why do disabled individuals have Individual Re...
# 327  110  203678  What's included in an Individual Rehabilitatio...
# 330  111  205286         How to obtain a National ID in Kazakhstan?
# 333  112  140682  Procedure for replacing a lost National ID in ...
# 336  113   98515  Restoring a lost National ID in the Republic o...
# 339  114     257  What is apostilization and document legalization?
# 342  115  203229  Why do you need to apostilize or legalize docu...
# 345  116     128                    What is diploma nostrification?
# 348  117     128  When is diploma nostrification required in Kaz...
# 351  118     575  Procedure for validating a foreign diploma in ...
# 354  119     128     Nostrification of foreign university diplomas.
# 357  120  128617             How to change your name in Kazakhstan?
# 360  121     138  Requirements for changing surname, name, or pa...
# 363  122  206110  Process of changing name due to marriage or di...
# 366  123  128617         Can I change my name online in Kazakhstan?
# 369  124  128617  Documents needed for a name change in Kazakhstan.
#
#                                                   text             file  rank
# 0    алғашқы медициналық-санитариялық көмек көрсете...         services     1
# 3    issuance of id cards to stateless persons and ...         services     1
# 6    new service for the pregnant available on egov...             news     1
# 9    telegram bot features we are already used to t...             news     1
# 12   what public services can be obtained online wi...             news     1
# 15   issuance of certificate from antituberculous o...         services     1
# 18   issuance of certificate from antituberculous o...         services     1
# 21   issuance of certificate from antituberculous o...         services     1
# 24   выдача разрешения на экспорт и (или) импорт от...         services     1
# 27   выдача разрешения на экспорт и (или) импорт от...         services     1
# 30   выдача лицензии на импорт и (или) экспорт отде...         services     1
# 33   provision of innovative scholarships for comme...         services     1
# 36   provision of innovative scholarships for comme...         services     1
# 39   provision of innovative scholarships for comme...         services     1
# 42   provision of guarantee letter for those who go...         services     1
# 45   усыновление (удочерение) ребенка какие дети, п...  life_situations     1
# 48   регистрация усыновления (удочерения), в том чи...         services     1
# 51   регистрация усыновления (удочерения), в том чи...         services     1
# 54   выдача разрешений на эмиссии в окружающую сред...         services     1
# 57   выдача разрешений на эмиссии в окружающую сред...         services     1
# 60   выдача разрешений на эмиссии в окружающую сред...         services     1
# 222  о сроках оплаты налога на имущество с физическ...         articles     1
# 225  налог на имущество упрощение уплаты налога на ...         articles     1
# 228                                      бюджет бюджет         articles     1
# 231  в кызылорде гвардейцы нашли без вести пропавше...             news     1
# 234  что делать если пропал человек как найти самос...  life_situations     1
# 237  не теряйте близких! даже самые внимательные ро...             news     1
# 240  как получить удостоверение личности что такое ...  life_situations     1
# 243  как получить удостоверение личности что такое ...  life_situations     1
# 246  как получить удостоверение личности что такое ...  life_situations     1
# 249  расторжение брака сроки государственной регист...  life_situations     1
# 252  расторжение брака развод при несогласии/уклоне...  life_situations     1
# 255  расторжение брака развод при несогласии/уклоне...  life_situations     1
# 258  расторжение брака сроки государственной регист...  life_situations     1
# 261  выдача разрешения на размещение эмиссионных це...         services     1
# 264  итті қалай асырау және серуендету керек иттерд...  life_situations     1
# 267  итті қалай асырау және серуендету керек иесіні...  life_situations     1
# 270  об ответственном обращении с животными жануарл...         articles     1
# 273  өңірлерді дамытудың 2020 – 2025 жылдарға арнал...         articles     1
# 276                                 шетелде дауыс беру         articles     1
# 279  әскери билетті қалай алуға болады әскери  биле...  life_situations     1
# 282                                  мектепке орналасу             news     1
# 285  талдамалық есеп қазақстан республикасындағы ба...         articles     1
# 288                     басқа елдерден көлік сатып алу         articles     1
# 291  атаулы әлеуметтік көмекті қалай алуға болады  ...  life_situations     1
# 294                                   әлеуметтік көмек         articles     1
# 297                        бизнесті мемлекеттік қолдау         articles     1
# 300                             ол үшін не істеу керек             news     1
# 303  тұрғын үй көмегін тағайындау   тұрғын үй көмег...         services     1
# 306  қай сәттен бастап қазақстан республикасының аз...             news     1
# 309                             ол үшін не істеу керек             news     1
# 312                вакцинацияға қалай жазылуға болады?             news     1
# 315  you're going to buy an apartment  if there are...  life_situations     1
# 318  you're going to buy an apartment  buying a hom...  life_situations     1
# 321  what is an irp card (individual rehabilitation...  life_situations     1
# 324  what is an irp card (individual rehabilitation...  life_situations     1
# 327  what is an irp card (individual rehabilitation...  life_situations     1
# 330  obtainment of national id what is the national...  life_situations     1
# 333  many of us have lost our wallet with money and...             news     1
# 336  technical passport-how to restore in case of l...         articles     1
# 339  apostil of the official documents from the pro...         services     1
# 342  how to apostilize (legalize) documents documen...  life_situations     1
# 345  recognition and nostrification of educational ...         services     1
# 348  recognition and nostrification of educational ...         services     1
# 351  issue of certificates to command staff   issua...         services     1
# 354  recognition and nostrification of educational ...         services     1
# 357  about changing the name, patronymic, surname t...             news     1
# 360  register changes name, patronymic, surname, ch...         services     1
# 363  divorce retention or change of name upon divor...  life_situations     1
# 366  about changing the name, patronymic, surname t...             news     1
# 369  about changing the name, patronymic, surname t...             news     1

# %%
sub = test_vars[test_vars['rank'] ==1].copy()
sub['index'] = sub['index'].astype(int)
sub = sub.reset_index(drop=True)
sub = sub.set_index('id')
sub[['index']].to_csv("submissions/sub44.csv")
